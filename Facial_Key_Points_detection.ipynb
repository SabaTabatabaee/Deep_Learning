# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from IPython.display import display
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Preprocessing the Data

# %%
facialpoints_df = pd.read_csv('KeyFacialPoints.csv')

# %%
print(facialpoints_df.shape)
# Out:
# (2140, 31)

# %%
facialpoints_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2140 entries, 0 to 2139
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   left_eye_center_x          2140 non-null   float64
#  1   left_eye_center_y          2140 non-null   float64
#  2   right_eye_center_x         2140 non-null   float64
#  3   right_eye_center_y         2140 non-null   float64
#  4   left_eye_inner_corner_x    2140 non-null   float64
#  5   left_eye_inner_corner_y    2140 non-null   float64
#  6   left_eye_outer_corner_x    2140 non-null   float64
#  7   left_eye_outer_corner_y    2140 non-null   float64
#  8   right_eye_inner_corner_x   2140 non-null   float64
#  9   right_eye_inner_corner_y   2140 non-null   float64
#  10  right_eye_outer_corner_x   2140 non-null   float64
#  11  right_eye_outer_corner_y   2140 non-null   float64
#  12  left_eyebrow_inner_end_x   2140 non-null   float64
#  13  left_eyebrow_inner_end_y   2140 non-null   float64
#  14  left_eyebrow_outer_end_x   2140 non-null   float64
#  15  left_eyebrow_outer_end_y   2140 non-null   float64
#  16  right_eyebrow_inner_end_x  2140 non-null   float64
#  17  right_eyebrow_inner_end_y  2140 non-null   float64
#  18  right_eyebrow_outer_end_x  2140 non-null   float64
#  19  right_eyebrow_outer_end_y  2140 non-null   float64
#  20  nose_tip_x                 2140 non-null   float64
#  21  nose_tip_y                 2140 non-null   float64
#  22  mouth_left_corner_x        2140 non-null   float64
#  23  mouth_left_corner_y        2140 non-null   float64
#  24  mouth_right_corner_x       2140 non-null   float64
#  25  mouth_right_corner_y       2140 non-null   float64
#  26  mouth_center_top_lip_x     2140 non-null   float64
#  27  mouth_center_top_lip_y     2140 non-null   float64
#  28  mouth_center_bottom_lip_x  2140 non-null   float64
#  29  mouth_center_bottom_lip_y  2140 non-null   float64
#  30  Image                      2140 non-null   object
# dtypes: float64(30), object(1)
# memory usage: 518.4+ KB

# %%
# Since values for the image is given as space separated string, we will need to separate the values using ' ' as separator.
# Then convert this into numpy array using np.fromstring and convert the obtained 1D array into 2D array of shape (96,96)
facialpoints_df['Image'] = facialpoints_df['Image'].apply(lambda x: np.fromstring(x, dtype= int, sep = ' ').reshape(96,96))

# %%
facialpoints_df['Image'][1].shape
# Out:
# (96, 96)

# %%
facialpoints_df.isnull().sum()
# Out:
# left_eye_center_x            0
# left_eye_center_y            0
# right_eye_center_x           0
# right_eye_center_y           0
# left_eye_inner_corner_x      0
# left_eye_inner_corner_y      0
# left_eye_outer_corner_x      0
# left_eye_outer_corner_y      0
# right_eye_inner_corner_x     0
# right_eye_inner_corner_y     0
# right_eye_outer_corner_x     0
# right_eye_outer_corner_y     0
# left_eyebrow_inner_end_x     0
# left_eyebrow_inner_end_y     0
# left_eyebrow_outer_end_x     0
# left_eyebrow_outer_end_y     0
# right_eyebrow_inner_end_x    0
# right_eyebrow_inner_end_y    0
# right_eyebrow_outer_end_x    0
# right_eyebrow_outer_end_y    0
# nose_tip_x                   0
# nose_tip_y                   0
# mouth_left_corner_x          0
# mouth_left_corner_y          0
# mouth_right_corner_x         0
# mouth_right_corner_y         0
# mouth_center_top_lip_x       0
# mouth_center_top_lip_y       0
# mouth_center_bottom_lip_x    0
# mouth_center_bottom_lip_y    0
# Image                        0
# dtype: int64

# %%
print(f"mean: {facialpoints_df['right_eye_center_x'].mean()}, max: {facialpoints_df['right_eye_center_x'].max()}, min: {facialpoints_df['right_eye_center_x'].min()}")
# Out:
# mean: 29.640268564561495, max: 42.495171727, min: 18.9226106286

# %%
i = np.random.randint(1, len(facialpoints_df))
plt.imshow(facialpoints_df['Image'][i],cmap='gray')
plt.title('Random image');

# %%
plt.figure()
plt.imshow(facialpoints_df['Image'][i],cmap='gray')
for j in range(1,31,2):
        plt.plot(facialpoints_df.loc[i][j-1], facialpoints_df.loc[i][j], 'rx')

# %%
import random
fig = plt.figure(figsize=(20, 20))
for iter in range(16):
    i = np.random.randint(1, len(facialpoints_df))
    ax = fig.add_subplot(4, 4, iter+ 1)
    image = plt.imshow(facialpoints_df['Image'][i], cmap = 'gray')
    for j in range(1,31,2):
        plt.plot(facialpoints_df.loc[i][j-1], facialpoints_df.loc[i][j], 'rx')

# %% [markdown]
# # image augmentation (flipping, brightness)

# %%
import copy
facialpoints_df_copy = copy.copy(facialpoints_df)

# %%
columns = facialpoints_df_copy.columns[:-1]
columns
# Out:
# Index(['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x',
#        'right_eye_center_y', 'left_eye_inner_corner_x',
#        'left_eye_inner_corner_y', 'left_eye_outer_corner_x',
#        'left_eye_outer_corner_y', 'right_eye_inner_corner_x',
#        'right_eye_inner_corner_y', 'right_eye_outer_corner_x',
#        'right_eye_outer_corner_y', 'left_eyebrow_inner_end_x',
#        'left_eyebrow_inner_end_y', 'left_eyebrow_outer_end_x',
#        'left_eyebrow_outer_end_y', 'right_eyebrow_inner_end_x',
#        'right_eyebrow_inner_end_y', 'right_eyebrow_outer_end_x',
#        'right_eyebrow_outer_end_y', 'nose_tip_x', 'nose_tip_y',
#        'mouth_left_corner_x', 'mouth_left_corner_y', 'mouth_right_corner_x',
#        'mouth_right_corner_y', 'mouth_center_top_lip_x',
#        'mouth_center_top_lip_y', 'mouth_center_bottom_lip_x',
#        'mouth_center_bottom_lip_y'],
#       dtype='object')

# %%
facialpoints_df['Image'][0]
# Out:
# array([[238, 236, 237, ..., 250, 250, 250],
#        [235, 238, 236, ..., 249, 250, 251],
#        [237, 236, 237, ..., 251, 251, 250],
#        ...,
#        [186, 183, 181, ...,  52,  57,  60],
#        [189, 188, 207, ...,  61,  69,  78],
#        [191, 184, 184, ...,  70,  75,  90]])

# %%
plt.imshow(facialpoints_df['Image'][0], cmap = 'gray')

# %%
facialpoints_df_copy['Image'] = facialpoints_df_copy['Image'].apply(lambda x: np.flip(x, axis = 1)) #flip horizontally (x changes)

# %%
plt.imshow(facialpoints_df_copy['Image'][0], cmap = 'gray')

# %%
# Since we are flipping the images horizontally, y coordinate values would be the same
# X coordinate values only would need to change, all we have to do is to subtract our initial x-coordinate values from width of the image(96)
for i in range(len(columns)):
  if i%2 == 0:
    facialpoints_df_copy[columns[i]] = facialpoints_df_copy[columns[i]].apply(lambda x: 96. - float(x) )

# %%
plt.imshow(facialpoints_df['Image'][0],cmap='gray')
for j in range(1, 31, 2):
        plt.plot(facialpoints_df.loc[0][j-1], facialpoints_df.loc[0][j], 'rx')

# %%
plt.imshow(facialpoints_df_copy['Image'][0], cmap='gray')
for j in range(1, 31, 2):
        plt.plot(facialpoints_df_copy.loc[0][j-1], facialpoints_df_copy.loc[0][j], 'rx')

# %%
facialpoints_df_augmented = np.concatenate((facialpoints_df,facialpoints_df_copy))

# %%
facialpoints_df_augmented.shape
# Out:
# (4280, 31)

# %%
# we perform another image augmentation by randomly increasing images brightness
# We multiply pixel values by random values between 1 and 2 to increase the brightness of the image
# we clip the value between 0 and 255
import random

facialpoints_df_copy = copy.copy(facialpoints_df)
facialpoints_df_copy['Image'] = facialpoints_df['Image'].apply(lambda x:np.clip(random.uniform(1, 2) * x, 0.0, 255.0))
facialpoints_df_augmented = np.concatenate((facialpoints_df_augmented, facialpoints_df_copy))
facialpoints_df_augmented.shape
# Out:
# (6420, 31)

# %%
plt.imshow(facialpoints_df_copy['Image'][0], cmap = 'gray')
for j in range(1, 31, 2):
        plt.plot(facialpoints_df_copy.loc[0][j-1], facialpoints_df_copy.loc[0][j], 'rx')

# %%
facialpoints_df_copy = copy.copy(facialpoints_df)
facialpoints_df_copy['Image'] = facialpoints_df_copy['Image'].apply(lambda x: np.flip(x, axis = 0)) #flip horizontally (x changes)

# %%
plt.imshow(facialpoints_df_copy['Image'][0], cmap = 'gray')

# %%
# Since we are flipping the images vertically, x coordinate values would be the same
# y coordinate values only would need to change, all we have to do is to subtract our initial y-coordinate values from height of the image(96)
for i in range(len(columns)):
  if i%2 == 1:
    facialpoints_df_copy[columns[i]] = facialpoints_df_copy[columns[i]].apply(lambda x: 96. - float(x) )
plt.imshow(facialpoints_df_copy['Image'][0], cmap = 'gray')
for j in range(1, 31, 2):
        plt.plot(facialpoints_df_copy.loc[0][j-1], facialpoints_df_copy.loc[0][j], 'rx')

# %% [markdown]
# # normalization
# input is image
# outputs are facial key points

# %%
# image

img = facialpoints_df_augmented[:, 30] #images are located at this column which is column 31
                                        #but because the index starts from 0 we call column 30
img = img/255.
X = np.empty((len(img), 96, 96, 1))

#  we need to expand it's dimension from (96,96) to (96,96,1)
for i in range(len(img)):
  X[i,] = np.expand_dims(img[i], axis = 2)

X = np.asarray(X).astype(np.float32)
X.shape
# Out:
# (6420, 96, 96, 1)

# %%
# outputs
y = facialpoints_df_augmented[:,:30]
y = np.asarray(y).astype(np.float32)
y.shape
# Out:
# (6420, 30)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

# %%
fig = plt.figure(figsize=(20,20))
for i in range (64):
  ax = fig.add_subplot(8,8,i+1)
  image = plt.imshow(X_train[i].reshape(96,96),cmap = 'gray')
  for j in range (1,31,2):
    plt.plot(y_train[i][j-1], y_train[i][j], 'rx')

# %%
def res_block(X, filter, stage):

  # CONVOLUTIONAL BLOCK
  X_copy = X
  f1 , f2, f3 = filter

  # Main Path
  X = Conv2D(f1, (1,1), strides = (1,1), name ='res_'+str(stage)+'_conv_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = MaxPool2D((2,2))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_a')(X)
  X = Activation('relu')(X)

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_conv_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_b')(X)
  X = Activation('relu')(X)

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_c')(X)

  # Short path
  X_copy = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_copy', kernel_initializer= glorot_uniform(seed = 0))(X_copy)
  X_copy = MaxPool2D((2,2))(X_copy)
  X_copy = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_copy')(X_copy)

  # Add data from main and short paths
  X = Add()([X,X_copy])
  X = Activation('relu')(X)



  # IDENTITY BLOCK 1
  X_copy = X

  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_1_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_a')(X)
  X = Activation('relu')(X)

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_1_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_b')(X)
  X = Activation('relu')(X)

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_1_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_c')(X)

  # Add both paths together (the original input "identity")
  X = Add()([X,X_copy])
  X = Activation('relu')(X)



  # IDENTITY BLOCK 2
  X_copy = X

  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_2_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_a')(X)
  X = Activation('relu')(X)

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_2_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_b')(X)
  X = Activation('relu')(X)

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_2_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_c')(X)

  # Add both paths together (Note that we feed the original input as is hence the name "identity")
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  return X

# %%
input_shape = (96,96,1)

# Input tensor shape
X_input = Input(input_shape)

# Zero-padding
X = ZeroPadding2D((3,3))(X_input)

# Stage #1
X = Conv2D(64, (7,7), strides= (2,2), name = 'conv1', kernel_initializer= glorot_uniform(seed = 0))(X)
X = BatchNormalization(axis =3, name = 'bn_conv1')(X)
X = Activation('relu')(X)
X = MaxPooling2D((3,3), strides= (2,2))(X)

# Stage #2
X = res_block(X, filter= [64,64,256], stage= 2)

# Stage #3
X = res_block(X, filter= [128,128,512], stage= 3)


# Average Pooling
X = AveragePooling2D((2,2), name = 'Averagea_Pooling')(X)

# Final layer
X = Flatten()(X)
X = Dense(4096, activation = 'relu')(X)
X = Dropout(0.2)(X)
X = Dense(2048, activation = 'relu')(X)
X = Dropout(0.1)(X)
X = Dense(30, activation = 'relu')(X)


model = Model( inputs= X_input, outputs = X)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 1)]          0         []
#
#  zero_padding2d (ZeroPaddin  (None, 102, 102, 1)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1 (Conv2D)              (None, 48, 48, 64)           3200      ['zero_padding2d[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 48, 48, 64)           256       ['conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 48, 48, 64)           0         ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 64)           0         ['activation[0][0]']
#  D)
#
#  res_2_conv_a (Conv2D)       (None, 23, 23, 64)           4160      ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 11, 11, 64)           0         ['res_2_conv_a[0][0]']
#  g2D)
#
#  bn_2_conv_a (BatchNormaliz  (None, 11, 11, 64)           256       ['max_pooling2d_1[0][0]']
#  ation)
#
#  activation_1 (Activation)   (None, 11, 11, 64)           0         ['bn_2_conv_a[0][0]']
#
#  res_2_conv_b (Conv2D)       (None, 11, 11, 64)           36928     ['activation_1[0][0]']
#
#  bn_2_conv_b (BatchNormaliz  (None, 11, 11, 64)           256       ['res_2_conv_b[0][0]']
#  ation)
#
#  activation_2 (Activation)   (None, 11, 11, 64)           0         ['bn_2_conv_b[0][0]']
#
#  res_2_conv_copy (Conv2D)    (None, 23, 23, 256)          16640     ['max_pooling2d[0][0]']
#
#  res_2_conv_c (Conv2D)       (None, 11, 11, 256)          16640     ['activation_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 11, 11, 256)          0         ['res_2_conv_copy[0][0]']
#  g2D)
#
#  bn_2_conv_c (BatchNormaliz  (None, 11, 11, 256)          1024      ['res_2_conv_c[0][0]']
#  ation)
#
#  bn_2_conv_copy (BatchNorma  (None, 11, 11, 256)          1024      ['max_pooling2d_2[0][0]']
#  lization)
#
#  add (Add)                   (None, 11, 11, 256)          0         ['bn_2_conv_c[0][0]',
#                                                                      'bn_2_conv_copy[0][0]']
#
#  activation_3 (Activation)   (None, 11, 11, 256)          0         ['add[0][0]']
#
#  res_2_identity_1_a (Conv2D  (None, 11, 11, 64)           16448     ['activation_3[0][0]']
#  )
#
#  bn_2_identity_1_a (BatchNo  (None, 11, 11, 64)           256       ['res_2_identity_1_a[0][0]']
#  rmalization)
#
#  activation_4 (Activation)   (None, 11, 11, 64)           0         ['bn_2_identity_1_a[0][0]']
#
#  res_2_identity_1_b (Conv2D  (None, 11, 11, 64)           36928     ['activation_4[0][0]']
#  )
#
#  bn_2_identity_1_b (BatchNo  (None, 11, 11, 64)           256       ['res_2_identity_1_b[0][0]']
#  rmalization)
#
#  activation_5 (Activation)   (None, 11, 11, 64)           0         ['bn_2_identity_1_b[0][0]']
#
#  res_2_identity_1_c (Conv2D  (None, 11, 11, 256)          16640     ['activation_5[0][0]']
#  )
#
#  bn_2_identity_1_c (BatchNo  (None, 11, 11, 256)          1024      ['res_2_identity_1_c[0][0]']
#  rmalization)
#
#  add_1 (Add)                 (None, 11, 11, 256)          0         ['bn_2_identity_1_c[0][0]',
#                                                                      'activation_3[0][0]']
#
#  activation_6 (Activation)   (None, 11, 11, 256)          0         ['add_1[0][0]']
#
#  res_2_identity_2_a (Conv2D  (None, 11, 11, 64)           16448     ['activation_6[0][0]']
#  )
#
#  bn_2_identity_2_a (BatchNo  (None, 11, 11, 64)           256       ['res_2_identity_2_a[0][0]']
#  rmalization)
#
#  activation_7 (Activation)   (None, 11, 11, 64)           0         ['bn_2_identity_2_a[0][0]']
#
#  res_2_identity_2_b (Conv2D  (None, 11, 11, 64)           36928     ['activation_7[0][0]']
#  )
#
#  bn_2_identity_2_b (BatchNo  (None, 11, 11, 64)           256       ['res_2_identity_2_b[0][0]']
#  rmalization)
#
#  activation_8 (Activation)   (None, 11, 11, 64)           0         ['bn_2_identity_2_b[0][0]']
#
#  res_2_identity_2_c (Conv2D  (None, 11, 11, 256)          16640     ['activation_8[0][0]']
#  )
#
#  bn_2_identity_2_c (BatchNo  (None, 11, 11, 256)          1024      ['res_2_identity_2_c[0][0]']
#  rmalization)
#
#  add_2 (Add)                 (None, 11, 11, 256)          0         ['bn_2_identity_2_c[0][0]',
#                                                                      'activation_6[0][0]']
#
#  activation_9 (Activation)   (None, 11, 11, 256)          0         ['add_2[0][0]']
#
#  res_3_conv_a (Conv2D)       (None, 11, 11, 128)          32896     ['activation_9[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 128)            0         ['res_3_conv_a[0][0]']
#  g2D)
#
#  bn_3_conv_a (BatchNormaliz  (None, 5, 5, 128)            512       ['max_pooling2d_3[0][0]']
#  ation)
#
#  activation_10 (Activation)  (None, 5, 5, 128)            0         ['bn_3_conv_a[0][0]']
#
#  res_3_conv_b (Conv2D)       (None, 5, 5, 128)            147584    ['activation_10[0][0]']
#
#  bn_3_conv_b (BatchNormaliz  (None, 5, 5, 128)            512       ['res_3_conv_b[0][0]']
#  ation)
#
#  activation_11 (Activation)  (None, 5, 5, 128)            0         ['bn_3_conv_b[0][0]']
#
#  res_3_conv_copy (Conv2D)    (None, 11, 11, 512)          131584    ['activation_9[0][0]']
#
#  res_3_conv_c (Conv2D)       (None, 5, 5, 512)            66048     ['activation_11[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 512)            0         ['res_3_conv_copy[0][0]']
#  g2D)
#
#  bn_3_conv_c (BatchNormaliz  (None, 5, 5, 512)            2048      ['res_3_conv_c[0][0]']
#  ation)
#
#  bn_3_conv_copy (BatchNorma  (None, 5, 5, 512)            2048      ['max_pooling2d_4[0][0]']
#  lization)
#
#  add_3 (Add)                 (None, 5, 5, 512)            0         ['bn_3_conv_c[0][0]',
#                                                                      'bn_3_conv_copy[0][0]']
#
#  activation_12 (Activation)  (None, 5, 5, 512)            0         ['add_3[0][0]']
#
#  res_3_identity_1_a (Conv2D  (None, 5, 5, 128)            65664     ['activation_12[0][0]']
#  )
#
#  bn_3_identity_1_a (BatchNo  (None, 5, 5, 128)            512       ['res_3_identity_1_a[0][0]']
#  rmalization)
#
#  activation_13 (Activation)  (None, 5, 5, 128)            0         ['bn_3_identity_1_a[0][0]']
#
#  res_3_identity_1_b (Conv2D  (None, 5, 5, 128)            147584    ['activation_13[0][0]']
#  )
#
#  bn_3_identity_1_b (BatchNo  (None, 5, 5, 128)            512       ['res_3_identity_1_b[0][0]']
#  rmalization)
#
#  activation_14 (Activation)  (None, 5, 5, 128)            0         ['bn_3_identity_1_b[0][0]']
#
#  res_3_identity_1_c (Conv2D  (None, 5, 5, 512)            66048     ['activation_14[0][0]']
#  )
#
#  bn_3_identity_1_c (BatchNo  (None, 5, 5, 512)            2048      ['res_3_identity_1_c[0][0]']
#  rmalization)
#
#  add_4 (Add)                 (None, 5, 5, 512)            0         ['bn_3_identity_1_c[0][0]',
#                                                                      'activation_12[0][0]']
#
#  activation_15 (Activation)  (None, 5, 5, 512)            0         ['add_4[0][0]']
#
#  res_3_identity_2_a (Conv2D  (None, 5, 5, 128)            65664     ['activation_15[0][0]']
#  )
#
#  bn_3_identity_2_a (BatchNo  (None, 5, 5, 128)            512       ['res_3_identity_2_a[0][0]']
#  rmalization)
#
#  activation_16 (Activation)  (None, 5, 5, 128)            0         ['bn_3_identity_2_a[0][0]']
#
#  res_3_identity_2_b (Conv2D  (None, 5, 5, 128)            147584    ['activation_16[0][0]']
#  )
#
#  bn_3_identity_2_b (BatchNo  (None, 5, 5, 128)            512       ['res_3_identity_2_b[0][0]']
#  rmalization)
#
#  activation_17 (Activation)  (None, 5, 5, 128)            0         ['bn_3_identity_2_b[0][0]']
#
#  res_3_identity_2_c (Conv2D  (None, 5, 5, 512)            66048     ['activation_17[0][0]']
#  )
#
#  bn_3_identity_2_c (BatchNo  (None, 5, 5, 512)            2048      ['res_3_identity_2_c[0][0]']
#  rmalization)
#
#  add_5 (Add)                 (None, 5, 5, 512)            0         ['bn_3_identity_2_c[0][0]',
#                                                                      'activation_15[0][0]']
#
#  activation_18 (Activation)  (None, 5, 5, 512)            0         ['add_5[0][0]']
#
#  Averagea_Pooling (AverageP  (None, 2, 2, 512)            0         ['activation_18[0][0]']
#  ooling2D)
#
#  flatten (Flatten)           (None, 2048)                 0         ['Averagea_Pooling[0][0]']
#
#  dense (Dense)               (None, 4096)                 8392704   ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 4096)                 0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 2048)                 8390656   ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 2048)                 0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 30)                   61470     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 18016286 (68.73 MB)
# Trainable params: 18007710 (68.69 MB)
# Non-trainable params: 8576 (33.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # train our model

# %%
adam = tf.keras.optimizers.Adam(learning_rate = 0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss="mean_squared_error", optimizer = adam, metrics = ['accuracy'])

# %%
# save the best model with least validation loss
checkpointer = ModelCheckpoint(filepath = "weights.hdf5", verbose = 1, save_best_only = True)

# %%
history = model.fit(X_train, y_train, batch_size = 256, epochs= 100, validation_split = 0.05, callbacks=[checkpointer])
# Out:
# Epoch 1/100
# 22/22 [==============================] - ETA: 0s - loss: 401.1029 - accuracy: 0.3434
# Epoch 1: val_loss improved from inf to 2187.92627, saving model to weights.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 22/22 [==============================] - 143s 6s/step - loss: 401.1029 - accuracy: 0.3434 - val_loss: 2187.9263 - val_accuracy: 0.0069
# Epoch 2/100
# 22/22 [==============================] - ETA: 0s - loss: 146.4603 - accuracy: 0.5170
# Epoch 2: val_loss improved from 2187.92627 to 1790.50439, saving model to weights.hdf5
# 22/22 [==============================] - 140s 6s/step - loss: 146.4603 - accuracy: 0.5170 - val_loss: 1790.5044 - val_accuracy: 0.7232
# Epoch 3/100
# 22/22 [==============================] - ETA: 0s - loss: 101.9845 - accuracy: 0.6048
# Epoch 3: val_loss improved from 1790.50439 to 1456.23596, saving model to weights.hdf5
# 22/22 [==============================] - 134s 6s/step - loss: 101.9845 - accuracy: 0.6048 - val_loss: 1456.2360 - val_accuracy: 0.7232
# Epoch 4/100
# 22/22 [==============================] - ETA: 0s - loss: 70.2067 - accuracy: 0.6041
# Epoch 4: val_loss improved from 1456.23596 to 1184.84167, saving model to weights.hdf5
# 22/22 [==============================] - 132s 6s/step - loss: 70.2067 - accuracy: 0.6041 - val_loss: 1184.8417 - val_accuracy: 0.7232
# Epoch 5/100
# 22/22 [==============================] - ETA: 0s - loss: 57.2910 - accuracy: 0.5977
# Epoch 5: val_loss improved from 1184.84167 to 952.25476, saving model to weights.hdf5
# 22/22 [==============================] - 132s 6s/step - loss: 57.2910 - accuracy: 0.5977 - val_loss: 952.2548 - val_accuracy: 0.7232
# Epoch 6/100
# 22/22 [==============================] - ETA: 0s - loss: 46.3436 - accuracy: 0.5912
# Epoch 6: val_loss improved from 952.25476 to 850.33807, saving model to weights.hdf5
# 22/22 [==============================] - 131s 6s/step - loss: 46.3436 - accuracy: 0.5912 - val_loss: 850.3381 - val_accuracy: 0.7232
# Epoch 7/100
# 22/22 [==============================] - ETA: 0s - loss: 37.5788 - accuracy: 0.5915
# Epoch 7: val_loss improved from 850.33807 to 602.11151, saving model to weights.hdf5
# 22/22 [==============================] - 135s 6s/step - loss: 37.5788 - accuracy: 0.5915 - val_loss: 602.1115 - val_accuracy: 0.7232
# Epoch 8/100
# 22/22 [==============================] - ETA: 0s - loss: 36.8242 - accuracy: 0.5968
# Epoch 8: val_loss improved from 602.11151 to 501.06760, saving model to weights.hdf5
# 22/22 [==============================] - 133s 6s/step - loss: 36.8242 - accuracy: 0.5968 - val_loss: 501.0676 - val_accuracy: 0.7232
# Epoch 9/100
# 22/22 [==============================] - ETA: 0s - loss: 40.5283 - accuracy: 0.5999
# Epoch 9: val_loss did not improve from 501.06760
# 22/22 [==============================] - 126s 6s/step - loss: 40.5283 - accuracy: 0.5999 - val_loss: 509.6437 - val_accuracy: 0.7232
# Epoch 10/100
# 22/22 [==============================] - ETA: 0s - loss: 28.1946 - accuracy: 0.6027
# Epoch 10: val_loss improved from 501.06760 to 368.00482, saving model to weights.hdf5
# 22/22 [==============================] - 132s 6s/step - loss: 28.1946 - accuracy: 0.6027 - val_loss: 368.0048 - val_accuracy: 0.7232
# Epoch 11/100
# 22/22 [==============================] - ETA: 0s - loss: 25.5407 - accuracy: 0.6129
# Epoch 11: val_loss improved from 368.00482 to 355.02759, saving model to weights.hdf5
# 22/22 [==============================] - 130s 6s/step - loss: 25.5407 - accuracy: 0.6129 - val_loss: 355.0276 - val_accuracy: 0.7232
# Epoch 12/100
# 22/22 [==============================] - ETA: 0s - loss: 22.5126 - accuracy: 0.6180
# Epoch 12: val_loss did not improve from 355.02759
# 22/22 [==============================] - 132s 6s/step - loss: 22.5126 - accuracy: 0.6180 - val_loss: 372.4528 - val_accuracy: 0.7232
# Epoch 13/100
# 22/22 [==============================] - ETA: 0s - loss: 23.2219 - accuracy: 0.6218
# Epoch 13: val_loss improved from 355.02759 to 246.71715, saving model to weights.hdf5
# 22/22 [==============================] - 133s 6s/step - loss: 23.2219 - accuracy: 0.6218 - val_loss: 246.7171 - val_accuracy: 0.7232
# Epoch 14/100
# 22/22 [==============================] - ETA: 0s - loss: 22.3782 - accuracy: 0.6229
# Epoch 14: val_loss improved from 246.71715 to 200.74561, saving model to weights.hdf5
# 22/22 [==============================] - 133s 6s/step - loss: 22.3782 - accuracy: 0.6229 - val_loss: 200.7456 - val_accuracy: 0.7232
# Epoch 15/100
# 22/22 [==============================] - ETA: 0s - loss: 21.5361 - accuracy: 0.6353
# Epoch 15: val_loss improved from 200.74561 to 177.57568, saving model to weights.hdf5
# 22/22 [==============================] - 131s 6s/step - loss: 21.5361 - accuracy: 0.6353 - val_loss: 177.5757 - val_accuracy: 0.7232
# Epoch 16/100
# 22/22 [==============================] - ETA: 0s - loss: 20.2975 - accuracy: 0.6320
# Epoch 16: val_loss improved from 177.57568 to 149.07251, saving model to weights.hdf5
# 22/22 [==============================] - 140s 6s/step - loss: 20.2975 - accuracy: 0.6320 - val_loss: 149.0725 - val_accuracy: 0.7232
# Epoch 17/100
# 22/22 [==============================] - ETA: 0s - loss: 18.1925 - accuracy: 0.6404
# Epoch 17: val_loss improved from 149.07251 to 127.39522, saving model to weights.hdf5
# 22/22 [==============================] - 130s 6s/step - loss: 18.1925 - accuracy: 0.6404 - val_loss: 127.3952 - val_accuracy: 0.7232
# Epoch 18/100
# 22/22 [==============================] - ETA: 0s - loss: 18.2682 - accuracy: 0.6371
# Epoch 18: val_loss did not improve from 127.39522
# 22/22 [==============================] - 126s 6s/step - loss: 18.2682 - accuracy: 0.6371 - val_loss: 138.3041 - val_accuracy: 0.7232
# Epoch 19/100
# 22/22 [==============================] - ETA: 0s - loss: 21.9191 - accuracy: 0.6529
# Epoch 19: val_loss did not improve from 127.39522
# 22/22 [==============================] - 129s 6s/step - loss: 21.9191 - accuracy: 0.6529 - val_loss: 145.8021 - val_accuracy: 0.7232
# Epoch 20/100
# 22/22 [==============================] - ETA: 0s - loss: 17.6929 - accuracy: 0.6356
# Epoch 20: val_loss improved from 127.39522 to 101.62794, saving model to weights.hdf5
# 22/22 [==============================] - 133s 6s/step - loss: 17.6929 - accuracy: 0.6356 - val_loss: 101.6279 - val_accuracy: 0.7232
# Epoch 21/100
# 22/22 [==============================] - ETA: 0s - loss: 14.5471 - accuracy: 0.6462
# Epoch 21: val_loss improved from 101.62794 to 92.77624, saving model to weights.hdf5
# 22/22 [==============================] - 140s 6s/step - loss: 14.5471 - accuracy: 0.6462 - val_loss: 92.7762 - val_accuracy: 0.7232
# Epoch 22/100
# 22/22 [==============================] - ETA: 0s - loss: 16.4597 - accuracy: 0.6508
# Epoch 22: val_loss improved from 92.77624 to 87.72742, saving model to weights.hdf5
# 22/22 [==============================] - 132s 6s/step - loss: 16.4597 - accuracy: 0.6508 - val_loss: 87.7274 - val_accuracy: 0.7232
# Epoch 23/100
# 22/22 [==============================] - ETA: 0s - loss: 21.1065 - accuracy: 0.6418
# Epoch 23: val_loss did not improve from 87.72742
# 22/22 [==============================] - 125s 6s/step - loss: 21.1065 - accuracy: 0.6418 - val_loss: 122.0759 - val_accuracy: 0.7197
# Epoch 24/100
# 22/22 [==============================] - ETA: 0s - loss: 16.5539 - accuracy: 0.6657
# Epoch 24: val_loss did not improve from 87.72742
# 22/22 [==============================] - 127s 6s/step - loss: 16.5539 - accuracy: 0.6657 - val_loss: 87.8279 - val_accuracy: 0.7197
# Epoch 25/100
# 22/22 [==============================] - ETA: 0s - loss: 15.3928 - accuracy: 0.6531
# Epoch 25: val_loss improved from 87.72742 to 85.02579, saving model to weights.hdf5
# 22/22 [==============================] - 131s 6s/step - loss: 15.3928 - accuracy: 0.6531 - val_loss: 85.0258 - val_accuracy: 0.7197
# Epoch 26/100
# 22/22 [==============================] - ETA: 0s - loss: 14.5547 - accuracy: 0.6590
# Epoch 26: val_loss improved from 85.02579 to 51.58684, saving model to weights.hdf5
# 22/22 [==============================] - 138s 6s/step - loss: 14.5547 - accuracy: 0.6590 - val_loss: 51.5868 - val_accuracy: 0.7301
# Epoch 27/100
# 22/22 [==============================] - ETA: 0s - loss: 13.2461 - accuracy: 0.6664
# Epoch 27: val_loss did not improve from 51.58684
# 22/22 [==============================] - 126s 6s/step - loss: 13.2461 - accuracy: 0.6664 - val_loss: 70.3883 - val_accuracy: 0.7059
# Epoch 28/100
# 22/22 [==============================] - ETA: 0s - loss: 11.8318 - accuracy: 0.6693
# Epoch 28: val_loss did not improve from 51.58684
# 22/22 [==============================] - 126s 6s/step - loss: 11.8318 - accuracy: 0.6693 - val_loss: 62.9643 - val_accuracy: 0.6644
# Epoch 29/100
# 22/22 [==============================] - ETA: 0s - loss: 12.4724 - accuracy: 0.6723
# Epoch 29: val_loss improved from 51.58684 to 46.12944, saving model to weights.hdf5
# 22/22 [==============================] - 131s 6s/step - loss: 12.4724 - accuracy: 0.6723 - val_loss: 46.1294 - val_accuracy: 0.7059
# Epoch 30/100
# 22/22 [==============================] - ETA: 0s - loss: 13.4205 - accuracy: 0.6801
# Epoch 30: val_loss did not improve from 46.12944
# 22/22 [==============================] - 133s 6s/step - loss: 13.4205 - accuracy: 0.6801 - val_loss: 58.0804 - val_accuracy: 0.7059
# Epoch 31/100
# 22/22 [==============================] - ETA: 0s - loss: 11.5060 - accuracy: 0.6808
# Epoch 31: val_loss did not improve from 46.12944
# 22/22 [==============================] - 127s 6s/step - loss: 11.5060 - accuracy: 0.6808 - val_loss: 48.4377 - val_accuracy: 0.6713
# Epoch 32/100
# 22/22 [==============================] - ETA: 0s - loss: 10.4315 - accuracy: 0.6848
# Epoch 32: val_loss did not improve from 46.12944
# 22/22 [==============================] - 128s 6s/step - loss: 10.4315 - accuracy: 0.6848 - val_loss: 50.2908 - val_accuracy: 0.6920
# Epoch 33/100
# 22/22 [==============================] - ETA: 0s - loss: 11.2172 - accuracy: 0.6834
# Epoch 33: val_loss did not improve from 46.12944
# 22/22 [==============================] - 127s 6s/step - loss: 11.2172 - accuracy: 0.6834 - val_loss: 55.9091 - val_accuracy: 0.7093
# Epoch 34/100
# 22/22 [==============================] - ETA: 0s - loss: 12.7250 - accuracy: 0.6856
# Epoch 34: val_loss did not improve from 46.12944
# 22/22 [==============================] - 127s 6s/step - loss: 12.7250 - accuracy: 0.6856 - val_loss: 48.4879 - val_accuracy: 0.7232
# Epoch 35/100
# 22/22 [==============================] - ETA: 0s - loss: 10.9966 - accuracy: 0.6883
# Epoch 35: val_loss did not improve from 46.12944
# 22/22 [==============================] - 128s 6s/step - loss: 10.9966 - accuracy: 0.6883 - val_loss: 50.1816 - val_accuracy: 0.7093
# Epoch 36/100
# 22/22 [==============================] - ETA: 0s - loss: 9.8163 - accuracy: 0.7021
# Epoch 36: val_loss improved from 46.12944 to 46.04500, saving model to weights.hdf5
# 22/22 [==============================] - 135s 6s/step - loss: 9.8163 - accuracy: 0.7021 - val_loss: 46.0450 - val_accuracy: 0.7232
# Epoch 37/100
# 22/22 [==============================] - ETA: 0s - loss: 10.0494 - accuracy: 0.7029
# Epoch 37: val_loss improved from 46.04500 to 42.02989, saving model to weights.hdf5
# 22/22 [==============================] - 132s 6s/step - loss: 10.0494 - accuracy: 0.7029 - val_loss: 42.0299 - val_accuracy: 0.6920
# Epoch 38/100
# 22/22 [==============================] - ETA: 0s - loss: 9.6449 - accuracy: 0.7029
# Epoch 38: val_loss did not improve from 42.02989
# 22/22 [==============================] - 127s 6s/step - loss: 9.6449 - accuracy: 0.7029 - val_loss: 54.0079 - val_accuracy: 0.6955
# Epoch 39/100
# 22/22 [==============================] - ETA: 0s - loss: 9.2107 - accuracy: 0.7010
# Epoch 39: val_loss did not improve from 42.02989
# 22/22 [==============================] - 127s 6s/step - loss: 9.2107 - accuracy: 0.7010 - val_loss: 49.9683 - val_accuracy: 0.6920
# Epoch 40/100
# 22/22 [==============================] - ETA: 0s - loss: 8.9605 - accuracy: 0.7158
# Epoch 40: val_loss did not improve from 42.02989
# 22/22 [==============================] - 125s 6s/step - loss: 8.9605 - accuracy: 0.7158 - val_loss: 44.5812 - val_accuracy: 0.6886
# Epoch 41/100
# 22/22 [==============================] - ETA: 0s - loss: 9.1417 - accuracy: 0.7043
# Epoch 41: val_loss improved from 42.02989 to 39.94474, saving model to weights.hdf5
# 22/22 [==============================] - 130s 6s/step - loss: 9.1417 - accuracy: 0.7043 - val_loss: 39.9447 - val_accuracy: 0.7059
# Epoch 42/100
# 22/22 [==============================] - ETA: 0s - loss: 15.5209 - accuracy: 0.6936
# Epoch 42: val_loss did not improve from 39.94474
# 22/22 [==============================] - 127s 6s/step - loss: 15.5209 - accuracy: 0.6936 - val_loss: 100.1989 - val_accuracy: 0.5744
# Epoch 43/100
# 22/22 [==============================] - ETA: 0s - loss: 17.6771 - accuracy: 0.6402
# Epoch 43: val_loss did not improve from 39.94474
# 22/22 [==============================] - 126s 6s/step - loss: 17.6771 - accuracy: 0.6402 - val_loss: 60.6703 - val_accuracy: 0.7128
# Epoch 44/100
# 22/22 [==============================] - ETA: 0s - loss: 14.0836 - accuracy: 0.6928
# Epoch 44: val_loss did not improve from 39.94474
# 22/22 [==============================] - 125s 6s/step - loss: 14.0836 - accuracy: 0.6928 - val_loss: 55.7495 - val_accuracy: 0.6782
# Epoch 45/100
# 22/22 [==============================] - ETA: 0s - loss: 13.5677 - accuracy: 0.6887
# Epoch 45: val_loss did not improve from 39.94474
# 22/22 [==============================] - 124s 6s/step - loss: 13.5677 - accuracy: 0.6887 - val_loss: 57.3734 - val_accuracy: 0.7059
# Epoch 46/100
# 22/22 [==============================] - ETA: 0s - loss: 13.1066 - accuracy: 0.6970
# Epoch 46: val_loss did not improve from 39.94474
# 22/22 [==============================] - 125s 6s/step - loss: 13.1066 - accuracy: 0.6970 - val_loss: 45.9109 - val_accuracy: 0.6782
# Epoch 47/100
# 22/22 [==============================] - ETA: 0s - loss: 9.9261 - accuracy: 0.6985
# Epoch 47: val_loss did not improve from 39.94474
# 22/22 [==============================] - 126s 6s/step - loss: 9.9261 - accuracy: 0.6985 - val_loss: 54.2496 - val_accuracy: 0.6990
# Epoch 48/100
# 22/22 [==============================] - ETA: 0s - loss: 13.7985 - accuracy: 0.7129
# Epoch 48: val_loss did not improve from 39.94474
# 22/22 [==============================] - 127s 6s/step - loss: 13.7985 - accuracy: 0.7129 - val_loss: 55.4728 - val_accuracy: 0.6817
# Epoch 49/100
# 22/22 [==============================] - ETA: 0s - loss: 10.0034 - accuracy: 0.6989
# Epoch 49: val_loss did not improve from 39.94474
# 22/22 [==============================] - 128s 6s/step - loss: 10.0034 - accuracy: 0.6989 - val_loss: 46.6944 - val_accuracy: 0.7370
# Epoch 50/100
# 22/22 [==============================] - ETA: 0s - loss: 9.4330 - accuracy: 0.7019
# Epoch 50: val_loss did not improve from 39.94474
# 22/22 [==============================] - 129s 6s/step - loss: 9.4330 - accuracy: 0.7019 - val_loss: 68.3333 - val_accuracy: 0.6505
# Epoch 51/100
# 22/22 [==============================] - ETA: 0s - loss: 9.6369 - accuracy: 0.7131
# Epoch 51: val_loss did not improve from 39.94474
# 22/22 [==============================] - 127s 6s/step - loss: 9.6369 - accuracy: 0.7131 - val_loss: 47.5047 - val_accuracy: 0.6955
# Epoch 52/100
# 22/22 [==============================] - ETA: 0s - loss: 9.5805 - accuracy: 0.7262
# Epoch 52: val_loss did not improve from 39.94474
# 22/22 [==============================] - 135s 6s/step - loss: 9.5805 - accuracy: 0.7262 - val_loss: 51.8491 - val_accuracy: 0.6574
# Epoch 53/100
# 22/22 [==============================] - ETA: 0s - loss: 9.3596 - accuracy: 0.7182
# Epoch 53: val_loss did not improve from 39.94474
# 22/22 [==============================] - 126s 6s/step - loss: 9.3596 - accuracy: 0.7182 - val_loss: 43.6612 - val_accuracy: 0.7266
# Epoch 54/100
# 22/22 [==============================] - ETA: 0s - loss: 8.7144 - accuracy: 0.7224
# Epoch 54: val_loss improved from 39.94474 to 37.05074, saving model to weights.hdf5
# 22/22 [==============================] - 131s 6s/step - loss: 8.7144 - accuracy: 0.7224 - val_loss: 37.0507 - val_accuracy: 0.7266
# Epoch 55/100
# 22/22 [==============================] - ETA: 0s - loss: 7.9783 - accuracy: 0.7302
# Epoch 55: val_loss did not improve from 37.05074
# 22/22 [==============================] - 128s 6s/step - loss: 7.9783 - accuracy: 0.7302 - val_loss: 41.8248 - val_accuracy: 0.7232
# Epoch 56/100
# 22/22 [==============================] - ETA: 0s - loss: 7.4366 - accuracy: 0.7260
# Epoch 56: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 7.4366 - accuracy: 0.7260 - val_loss: 48.4051 - val_accuracy: 0.7370
# Epoch 57/100
# 22/22 [==============================] - ETA: 0s - loss: 8.8391 - accuracy: 0.7304
# Epoch 57: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 8.8391 - accuracy: 0.7304 - val_loss: 48.2340 - val_accuracy: 0.6886
# Epoch 58/100
# 22/22 [==============================] - ETA: 0s - loss: 7.9338 - accuracy: 0.7220
# Epoch 58: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 7.9338 - accuracy: 0.7220 - val_loss: 47.4549 - val_accuracy: 0.6609
# Epoch 59/100
# 22/22 [==============================] - ETA: 0s - loss: 7.9833 - accuracy: 0.7324
# Epoch 59: val_loss did not improve from 37.05074
# 22/22 [==============================] - 128s 6s/step - loss: 7.9833 - accuracy: 0.7324 - val_loss: 41.2108 - val_accuracy: 0.7301
# Epoch 60/100
# 22/22 [==============================] - ETA: 0s - loss: 7.1493 - accuracy: 0.7402
# Epoch 60: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 7.1493 - accuracy: 0.7402 - val_loss: 45.2189 - val_accuracy: 0.7128
# Epoch 61/100
# 22/22 [==============================] - ETA: 0s - loss: 6.5269 - accuracy: 0.7459
# Epoch 61: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 6.5269 - accuracy: 0.7459 - val_loss: 48.9227 - val_accuracy: 0.7197
# Epoch 62/100
# 22/22 [==============================] - ETA: 0s - loss: 8.0993 - accuracy: 0.7428
# Epoch 62: val_loss did not improve from 37.05074
# 22/22 [==============================] - 128s 6s/step - loss: 8.0993 - accuracy: 0.7428 - val_loss: 38.4465 - val_accuracy: 0.7370
# Epoch 63/100
# 22/22 [==============================] - ETA: 0s - loss: 8.3923 - accuracy: 0.7449
# Epoch 63: val_loss did not improve from 37.05074
# 22/22 [==============================] - 128s 6s/step - loss: 8.3923 - accuracy: 0.7449 - val_loss: 44.5724 - val_accuracy: 0.7197
# Epoch 64/100
# 22/22 [==============================] - ETA: 0s - loss: 6.9827 - accuracy: 0.7484
# Epoch 64: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 6.9827 - accuracy: 0.7484 - val_loss: 38.2990 - val_accuracy: 0.7128
# Epoch 65/100
# 22/22 [==============================] - ETA: 0s - loss: 6.2795 - accuracy: 0.7380
# Epoch 65: val_loss did not improve from 37.05074
# 22/22 [==============================] - 128s 6s/step - loss: 6.2795 - accuracy: 0.7380 - val_loss: 46.7560 - val_accuracy: 0.7197
# Epoch 66/100
# 22/22 [==============================] - ETA: 0s - loss: 9.3294 - accuracy: 0.7426
# Epoch 66: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 9.3294 - accuracy: 0.7426 - val_loss: 48.7346 - val_accuracy: 0.7232
# Epoch 67/100
# 22/22 [==============================] - ETA: 0s - loss: 6.3476 - accuracy: 0.7495
# Epoch 67: val_loss did not improve from 37.05074
# 22/22 [==============================] - 126s 6s/step - loss: 6.3476 - accuracy: 0.7495 - val_loss: 44.0261 - val_accuracy: 0.7301
# Epoch 68/100
# 22/22 [==============================] - ETA: 0s - loss: 6.2086 - accuracy: 0.7479
# Epoch 68: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 6.2086 - accuracy: 0.7479 - val_loss: 45.3064 - val_accuracy: 0.7370
# Epoch 69/100
# 22/22 [==============================] - ETA: 0s - loss: 7.8408 - accuracy: 0.7577
# Epoch 69: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 7.8408 - accuracy: 0.7577 - val_loss: 45.5097 - val_accuracy: 0.7232
# Epoch 70/100
# 22/22 [==============================] - ETA: 0s - loss: 5.8590 - accuracy: 0.7448
# Epoch 70: val_loss did not improve from 37.05074
# 22/22 [==============================] - 124s 6s/step - loss: 5.8590 - accuracy: 0.7448 - val_loss: 50.1283 - val_accuracy: 0.7336
# Epoch 71/100
# 22/22 [==============================] - ETA: 0s - loss: 8.1311 - accuracy: 0.7510
# Epoch 71: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 8.1311 - accuracy: 0.7510 - val_loss: 46.4837 - val_accuracy: 0.7474
# Epoch 72/100
# 22/22 [==============================] - ETA: 0s - loss: 5.8218 - accuracy: 0.7471
# Epoch 72: val_loss did not improve from 37.05074
# 22/22 [==============================] - 126s 6s/step - loss: 5.8218 - accuracy: 0.7471 - val_loss: 45.7402 - val_accuracy: 0.7509
# Epoch 73/100
# 22/22 [==============================] - ETA: 0s - loss: 5.3892 - accuracy: 0.7590
# Epoch 73: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 5.3892 - accuracy: 0.7590 - val_loss: 46.4309 - val_accuracy: 0.7439
# Epoch 74/100
# 22/22 [==============================] - ETA: 0s - loss: 6.0511 - accuracy: 0.7541
# Epoch 74: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 6.0511 - accuracy: 0.7541 - val_loss: 45.0043 - val_accuracy: 0.7405
# Epoch 75/100
# 22/22 [==============================] - ETA: 0s - loss: 5.1412 - accuracy: 0.7619
# Epoch 75: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 5.1412 - accuracy: 0.7619 - val_loss: 43.8223 - val_accuracy: 0.7543
# Epoch 76/100
# 22/22 [==============================] - ETA: 0s - loss: 5.1248 - accuracy: 0.7590
# Epoch 76: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 5.1248 - accuracy: 0.7590 - val_loss: 44.2467 - val_accuracy: 0.7647
# Epoch 77/100
# 22/22 [==============================] - ETA: 0s - loss: 5.5935 - accuracy: 0.7623
# Epoch 77: val_loss did not improve from 37.05074
# 22/22 [==============================] - 126s 6s/step - loss: 5.5935 - accuracy: 0.7623 - val_loss: 46.2328 - val_accuracy: 0.7578
# Epoch 78/100
# 22/22 [==============================] - ETA: 0s - loss: 5.1558 - accuracy: 0.7593
# Epoch 78: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 5.1558 - accuracy: 0.7593 - val_loss: 45.5260 - val_accuracy: 0.7647
# Epoch 79/100
# 22/22 [==============================] - ETA: 0s - loss: 5.1894 - accuracy: 0.7646
# Epoch 79: val_loss did not improve from 37.05074
# 22/22 [==============================] - 126s 6s/step - loss: 5.1894 - accuracy: 0.7646 - val_loss: 44.4672 - val_accuracy: 0.7785
# Epoch 80/100
# 22/22 [==============================] - ETA: 0s - loss: 5.8319 - accuracy: 0.7670
# Epoch 80: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 5.8319 - accuracy: 0.7670 - val_loss: 43.2822 - val_accuracy: 0.7578
# Epoch 81/100
# 22/22 [==============================] - ETA: 0s - loss: 5.0545 - accuracy: 0.7699
# Epoch 81: val_loss did not improve from 37.05074
# 22/22 [==============================] - 128s 6s/step - loss: 5.0545 - accuracy: 0.7699 - val_loss: 43.0891 - val_accuracy: 0.7612
# Epoch 82/100
# 22/22 [==============================] - ETA: 0s - loss: 4.9055 - accuracy: 0.7735
# Epoch 82: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 4.9055 - accuracy: 0.7735 - val_loss: 42.8054 - val_accuracy: 0.7716
# Epoch 83/100
# 22/22 [==============================] - ETA: 0s - loss: 5.6783 - accuracy: 0.7699
# Epoch 83: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 5.6783 - accuracy: 0.7699 - val_loss: 43.2521 - val_accuracy: 0.7543
# Epoch 84/100
# 22/22 [==============================] - ETA: 0s - loss: 6.8952 - accuracy: 0.7734
# Epoch 84: val_loss did not improve from 37.05074
# 22/22 [==============================] - 126s 6s/step - loss: 6.8952 - accuracy: 0.7734 - val_loss: 43.8539 - val_accuracy: 0.7474
# Epoch 85/100
# 22/22 [==============================] - ETA: 0s - loss: 6.1445 - accuracy: 0.7741
# Epoch 85: val_loss did not improve from 37.05074
# 22/22 [==============================] - 123s 6s/step - loss: 6.1445 - accuracy: 0.7741 - val_loss: 45.0637 - val_accuracy: 0.7612
# Epoch 86/100
# 22/22 [==============================] - ETA: 0s - loss: 6.7713 - accuracy: 0.7734
# Epoch 86: val_loss did not improve from 37.05074
# 22/22 [==============================] - 126s 6s/step - loss: 6.7713 - accuracy: 0.7734 - val_loss: 49.1967 - val_accuracy: 0.7751
# Epoch 87/100
# 22/22 [==============================] - ETA: 0s - loss: 10.4680 - accuracy: 0.7737
# Epoch 87: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 10.4680 - accuracy: 0.7737 - val_loss: 53.5161 - val_accuracy: 0.7543
# Epoch 88/100
# 22/22 [==============================] - ETA: 0s - loss: 11.2871 - accuracy: 0.7637
# Epoch 88: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 11.2871 - accuracy: 0.7637 - val_loss: 42.7469 - val_accuracy: 0.7474
# Epoch 89/100
# 22/22 [==============================] - ETA: 0s - loss: 5.5004 - accuracy: 0.7788
# Epoch 89: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 5.5004 - accuracy: 0.7788 - val_loss: 44.3707 - val_accuracy: 0.7647
# Epoch 90/100
# 22/22 [==============================] - ETA: 0s - loss: 4.6735 - accuracy: 0.7781
# Epoch 90: val_loss did not improve from 37.05074
# 22/22 [==============================] - 126s 6s/step - loss: 4.6735 - accuracy: 0.7781 - val_loss: 44.2735 - val_accuracy: 0.7716
# Epoch 91/100
# 22/22 [==============================] - ETA: 0s - loss: 4.6703 - accuracy: 0.7777
# Epoch 91: val_loss did not improve from 37.05074
# 22/22 [==============================] - 126s 6s/step - loss: 4.6703 - accuracy: 0.7777 - val_loss: 43.0429 - val_accuracy: 0.7509
# Epoch 92/100
# 22/22 [==============================] - ETA: 0s - loss: 4.9241 - accuracy: 0.7768
# Epoch 92: val_loss did not improve from 37.05074
# 22/22 [==============================] - 126s 6s/step - loss: 4.9241 - accuracy: 0.7768 - val_loss: 42.5415 - val_accuracy: 0.7716
# Epoch 93/100
# 22/22 [==============================] - ETA: 0s - loss: 5.8678 - accuracy: 0.7870
# Epoch 93: val_loss did not improve from 37.05074
# 22/22 [==============================] - 128s 6s/step - loss: 5.8678 - accuracy: 0.7870 - val_loss: 42.4256 - val_accuracy: 0.7751
# Epoch 94/100
# 22/22 [==============================] - ETA: 0s - loss: 4.6875 - accuracy: 0.7894
# Epoch 94: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 4.6875 - accuracy: 0.7894 - val_loss: 41.1544 - val_accuracy: 0.7682
# Epoch 95/100
# 22/22 [==============================] - ETA: 0s - loss: 4.7488 - accuracy: 0.7814
# Epoch 95: val_loss did not improve from 37.05074
# 22/22 [==============================] - 125s 6s/step - loss: 4.7488 - accuracy: 0.7814 - val_loss: 42.3043 - val_accuracy: 0.7751
# Epoch 96/100
# 22/22 [==============================] - ETA: 0s - loss: 4.4507 - accuracy: 0.7874
# Epoch 96: val_loss did not improve from 37.05074
# 22/22 [==============================] - 127s 6s/step - loss: 4.4507 - accuracy: 0.7874 - val_loss: 41.7928 - val_accuracy: 0.7751
# Epoch 97/100
# 22/22 [==============================] - ETA: 0s - loss: 4.4449 - accuracy: 0.7890
# Epoch 97: val_loss did not improve from 37.05074
# 22/22 [==============================] - 124s 6s/step - loss: 4.4449 - accuracy: 0.7890 - val_loss: 42.4801 - val_accuracy: 0.7993
# Epoch 98/100
# 22/22 [==============================] - ETA: 0s - loss: 4.3102 - accuracy: 0.7910
# Epoch 98: val_loss did not improve from 37.05074
# 22/22 [==============================] - 128s 6s/step - loss: 4.3102 - accuracy: 0.7910 - val_loss: 41.7641 - val_accuracy: 0.7855
# Epoch 99/100
# 22/22 [==============================] - ETA: 0s - loss: 4.3912 - accuracy: 0.7976
# Epoch 99: val_loss did not improve from 37.05074
# 22/22 [==============================] - 124s 6s/step - loss: 4.3912 - accuracy: 0.7976 - val_loss: 42.5229 - val_accuracy: 0.7820
# Epoch 100/100
# 22/22 [==============================] - ETA: 0s - loss: 4.1183 - accuracy: 0.7932
# Epoch 100: val_loss did not improve from 37.05074
# 22/22 [==============================] - 126s 6s/step - loss: 4.1183 - accuracy: 0.7932 - val_loss: 43.8770 - val_accuracy: 0.7889

# %%
model_json = model.to_json()
with open('KeyPointDetector.json', 'w') as json_file:
        json_file.write(model_json)

# %%
with open('KeyPointDetector.json', 'r') as json_file:
    json_SavedModel = json_file.read()
model = tf.keras.models.model_from_json(json_SavedModel)
model.load_weights('weights.hdf5')
model.compile(loss="mean_squared_error", optimizer = adam, metrics = ['accuracy'])

# %%
result = model.evaluate(X_test,y_test)
print("Accuracy : {}".format(result[1]))
# Out:
# 21/21 [==============================] - 4s 140ms/step - loss: 51.2539 - accuracy: 0.7025
# Accuracy : 0.7024922370910645

# %%
# Make prediction using the testing dataset
df_predict = model.predict(X_test)
# Out:
# 21/21 [==============================] - 4s 141ms/step

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(y_test, df_predict))
print("RMSE value : {}".format(rms))
# Out:
# RMSE value : 7.159181485834756

# %%
# we convert the predicted values into a dataframe

df_predict= pd.DataFrame(df_predict, columns = columns)
df_predict.head()
# Out:
#    left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0          65.060760          35.895462           27.549078
# 1          66.235756          37.114662           29.576008
# 2          66.658989          37.167969           29.004862
# 3          29.052271          35.921898           65.814285
# 4          31.763987          36.208328           59.325417
#
#    right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0           36.797134                56.653332                37.599052
# 1           36.648594                59.983757                37.457027
# 2           38.105553                59.020672                38.247879
# 3           35.902332                36.721134                36.907249
# 4           34.029041                37.548336                37.058147
#
#    left_eye_outer_corner_x  left_eye_outer_corner_y  right_eye_inner_corner_x  \
# 0                72.585136                36.354031                 36.382450
# 1                71.974373                38.033455                 35.761684
# 2                73.425056                37.498100                 35.633541
# 3                20.640873                36.671883                 58.497364
# 4                25.653517                36.684227                 53.461140
#
#    right_eye_inner_corner_y  ...  nose_tip_x  nose_tip_y  mouth_left_corner_x  \
# 0                 38.315254  ...   50.004971   62.434803            62.623413
# 1                 37.296627  ...   47.583488   54.028481            61.753525
# 2                 38.919605  ...   46.651970   59.263329            64.733627
# 3                 36.933830  ...   47.844551   56.159428            31.397499
# 4                 35.934177  ...   44.480000   60.608135            35.835705
#
#    mouth_left_corner_y  mouth_right_corner_x  mouth_right_corner_y  \
# 0            80.313004             31.327467             81.987122
# 1            73.912125             33.818859             73.665474
# 2            75.846313             34.250202             77.054070
# 3            74.704407             63.965611             74.563026
# 4            72.566620             59.938877             70.533806
#
#    mouth_center_top_lip_x  mouth_center_top_lip_y  mouth_center_bottom_lip_x  \
# 0               48.172138               81.687386                  48.063683
# 1               47.324528               67.447433                  47.399361
# 2               48.371239               73.800697                  48.881523
# 3               47.965649               72.355080                  47.738422
# 4               46.888222               73.675163                  46.873840
#
#    mouth_center_bottom_lip_y
# 0                  82.473976
# 1                  82.070793
# 2                  83.768204
# 3                  81.204819
# 4                  75.714134
#
# [5 rows x 30 columns]

# %%
# we plot the test images and their predicted keypoints

fig = plt.figure(figsize=(20, 20))

for i in range(8):
    ax = fig.add_subplot(4, 2, i + 1)
    # Using squeeze to convert the image shape from (96,96,1) to (96,96)
    plt.imshow(X_test[i].squeeze(),cmap='gray')
    for j in range(1,31,2):
            plt.plot(df_predict.loc[i][j-1], df_predict.loc[i][j], 'rx')
